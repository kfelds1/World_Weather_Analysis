# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 741

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')


            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | ulladulla
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | saint-pierre
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | aksarka
# Processing Record 10 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 1 | nuuk
# Processing Record 12 of Set 1 | alofi
# Processing Record 13 of Set 1 | rio gallegos
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | bestobe
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | port hedland
# Processing Record 22 of Set 1 | lavrentiya
# Processing Record 23 of Set 1 | kingman
# Processing Record 24 of Set 1 | mount isa
# Processing Record 25 of Set 1 | helena
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | praia
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | beringovskiy
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 1 | namatanai
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | ferrol
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | san cristobal
# Processing Record 43 of Set 1 | russkaya polyana
# Processing Record 44 of Set 1 | panjab
# Processing Record 45 of Set 1 | puerto escondido
# Processing Record 46 of Set 1 | umm lajj
# Processing Record 47 of Set 1 | sarapul
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | nabire
# Processing Record 1 of Set 2 | vangaindrano
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | bengkulu
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | lircay
# Processing Record 7 of Set 2 | leh
# Processing Record 8 of Set 2 | ushuaia
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | isangel
# Processing Record 11 of Set 2 | souillac
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | camacha
# Processing Record 14 of Set 2 | lagoa
# Processing Record 15 of Set 2 | port macquarie
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | masindi
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | palana
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 2 | esperance
# Processing Record 23 of Set 2 | lompoc
# Processing Record 24 of Set 2 | palmer
# Processing Record 25 of Set 2 | nantucket
# Processing Record 26 of Set 2 | constitucion
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | pilar
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | bilibino
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | tiznit
# Processing Record 33 of Set 2 | paucartambo
# City not found. Skipping...
# Processing Record 34 of Set 2 | shingu
# Processing Record 35 of Set 2 | quelimane
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | anadyr
# Processing Record 39 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | san patricio
# Processing Record 43 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 44 of Set 2 | inirida
# Processing Record 45 of Set 2 | vila franca do campo
# Processing Record 46 of Set 2 | levelland
# Processing Record 47 of Set 2 | emerald
# Processing Record 48 of Set 2 | wrzesnia
# Processing Record 49 of Set 2 | pevek
# Processing Record 50 of Set 2 | yumen
# Processing Record 1 of Set 3 | praia da vitoria
# Processing Record 2 of Set 3 | evensk
# Processing Record 3 of Set 3 | vanavara
# Processing Record 4 of Set 3 | musoma
# Processing Record 5 of Set 3 | palauig
# Processing Record 6 of Set 3 | aykhal
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | nanortalik
# Processing Record 9 of Set 3 | vardo
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | kungurtug
# Processing Record 12 of Set 3 | freetown
# Processing Record 13 of Set 3 | port pirie
# Processing Record 14 of Set 3 | champerico
# Processing Record 15 of Set 3 | dingle
# Processing Record 16 of Set 3 | dobson
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | kincardine
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | almaznyy
# Processing Record 21 of Set 3 | dalvik
# Processing Record 22 of Set 3 | kosh-agach
# Processing Record 23 of Set 3 | butaritari
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | coahuayana
# Processing Record 26 of Set 3 | zion
# Processing Record 27 of Set 3 | ambilobe
# Processing Record 28 of Set 3 | hwange
# Processing Record 29 of Set 3 | severo-kurilsk
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | rio grande
# Processing Record 33 of Set 3 | adrar
# Processing Record 34 of Set 3 | ihosy
# Processing Record 35 of Set 3 | husavik
# Processing Record 36 of Set 3 | sola
# Processing Record 37 of Set 3 | shatsk
# Processing Record 38 of Set 3 | inhambane
# Processing Record 39 of Set 3 | hervey bay
# Processing Record 40 of Set 3 | fillmore
# Processing Record 41 of Set 3 | tukrah
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | cabo san lucas
# Processing Record 44 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 3 | morondava
# Processing Record 46 of Set 3 | east london
# Processing Record 47 of Set 3 | torbay
# Processing Record 48 of Set 3 | richard toll
# City not found. Skipping...
# Processing Record 49 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 3 | dzerzhinskoye
# Processing Record 1 of Set 4 | zyryanka
# Processing Record 2 of Set 4 | arraial do cabo
# Processing Record 3 of Set 4 | port blair
# Processing Record 4 of Set 4 | stokmarknes
# Processing Record 5 of Set 4 | deputatskiy
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | humaita
# Processing Record 10 of Set 4 | san pedro
# Processing Record 11 of Set 4 | shumskiy
# Processing Record 12 of Set 4 | skibbereen
# Processing Record 13 of Set 4 | geraldton
# Processing Record 14 of Set 4 | thinadhoo
# Processing Record 15 of Set 4 | sitka
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 4 | angoche
# Processing Record 20 of Set 4 | tromso
# Processing Record 21 of Set 4 | wadena
# Processing Record 22 of Set 4 | vaini
# Processing Record 23 of Set 4 | busselton
# Processing Record 24 of Set 4 | alyangula
# Processing Record 25 of Set 4 | parchim
# Processing Record 26 of Set 4 | natal
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | gorin
# Processing Record 29 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 4 | verkhoyansk
# Processing Record 31 of Set 4 | porosozero
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | phangnga
# Processing Record 34 of Set 4 | laguna
# Processing Record 35 of Set 4 | kibala
# Processing Record 36 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 4 | brae
# Processing Record 38 of Set 4 | saint anthony
# Processing Record 39 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 4 | manitowoc
# Processing Record 41 of Set 4 | bubaque
# Processing Record 42 of Set 4 | krasnoselkup
# Processing Record 43 of Set 4 | saint-leu
# Processing Record 44 of Set 4 | tuatapere
# Processing Record 45 of Set 4 | summerside
# Processing Record 46 of Set 4 | loreto
# Processing Record 47 of Set 4 | pestravka
# Processing Record 48 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 4 | kalmar
# Processing Record 50 of Set 4 | sumbuya
# Processing Record 1 of Set 5 | cotonou
# Processing Record 2 of Set 5 | touros
# Processing Record 3 of Set 5 | santiago
# Processing Record 4 of Set 5 | itarema
# Processing Record 5 of Set 5 | korla
# Processing Record 6 of Set 5 | birjand
# Processing Record 7 of Set 5 | wagar
# Processing Record 8 of Set 5 | sao felipe
# Processing Record 9 of Set 5 | istria
# Processing Record 10 of Set 5 | dillon
# Processing Record 11 of Set 5 | labuhan
# Processing Record 12 of Set 5 | tekeli
# Processing Record 13 of Set 5 | nambour
# Processing Record 14 of Set 5 | new norfolk
# Processing Record 15 of Set 5 | haines junction
# Processing Record 16 of Set 5 | xining
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 5 | ulkan
# Processing Record 20 of Set 5 | dicabisagan
# Processing Record 21 of Set 5 | port hardy
# Processing Record 22 of Set 5 | pokhara
# Processing Record 23 of Set 5 | aksay
# Processing Record 24 of Set 5 | pacific grove
# Processing Record 25 of Set 5 | iranshahr
# Processing Record 26 of Set 5 | weinan
# Processing Record 27 of Set 5 | merauke
# Processing Record 28 of Set 5 | kahului
# Processing Record 29 of Set 5 | juneau
# Processing Record 30 of Set 5 | punta de piedra
# Processing Record 31 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 5 | tambopata
# Processing Record 33 of Set 5 | gotsu
# Processing Record 34 of Set 5 | graaff-reinet
# Processing Record 35 of Set 5 | novyy svit
# Processing Record 36 of Set 5 | hilo
# Processing Record 37 of Set 5 | masalli
# Processing Record 38 of Set 5 | bay roberts
# Processing Record 39 of Set 5 | robertson
# Processing Record 40 of Set 5 | mangai
# Processing Record 41 of Set 5 | hovd
# Processing Record 42 of Set 5 | pandan niog
# Processing Record 43 of Set 5 | harper
# Processing Record 44 of Set 5 | batagay-alyta
# Processing Record 45 of Set 5 | ghanzi
# Processing Record 46 of Set 5 | clyde river
# Processing Record 47 of Set 5 | fortuna
# Processing Record 48 of Set 5 | barranca
# Processing Record 49 of Set 5 | chicama
# Processing Record 50 of Set 5 | coronado
# Processing Record 1 of Set 6 | ostrovnoy
# Processing Record 2 of Set 6 | khandyga
# Processing Record 3 of Set 6 | bambous virieux
# Processing Record 4 of Set 6 | mitchell
# Processing Record 5 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 6 | grand gaube
# Processing Record 7 of Set 6 | lichtenburg
# Processing Record 8 of Set 6 | los llanos de aridane
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | kodiak
# Processing Record 11 of Set 6 | coihaique
# Processing Record 12 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 6 | kozhva
# Processing Record 14 of Set 6 | libertador general san martin
# Processing Record 15 of Set 6 | san jose
# Processing Record 16 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 17 of Set 6 | itoman
# Processing Record 18 of Set 6 | provideniya
# Processing Record 19 of Set 6 | ormoz
# Processing Record 20 of Set 6 | encruzilhada
# Processing Record 21 of Set 6 | gebre guracha
# Processing Record 22 of Set 6 | madera
# Processing Record 23 of Set 6 | saldanha
# Processing Record 24 of Set 6 | tilichiki
# Processing Record 25 of Set 6 | rumford
# Processing Record 26 of Set 6 | severo-yeniseyskiy
# Processing Record 27 of Set 6 | tarko-sale
# Processing Record 28 of Set 6 | nieves
# Processing Record 29 of Set 6 | punta gorda
# Processing Record 30 of Set 6 | salalah
# Processing Record 31 of Set 6 | jashpurnagar
# Processing Record 32 of Set 6 | tahta
# Processing Record 33 of Set 6 | grindavik
# Processing Record 34 of Set 6 | avera
# Processing Record 35 of Set 6 | antropovo
# Processing Record 36 of Set 6 | hobyo
# Processing Record 37 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 6 | chapais
# Processing Record 39 of Set 6 | makat
# Processing Record 40 of Set 6 | hambantota
# Processing Record 41 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 6 | broome
# Processing Record 43 of Set 6 | rusera
# Processing Record 44 of Set 6 | australind
# Processing Record 45 of Set 6 | aklavik
# Processing Record 46 of Set 6 | ariano irpino
# Processing Record 47 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 6 | mazagao
# Processing Record 49 of Set 6 | trinidad
# Processing Record 50 of Set 6 | aranda de duero
# Processing Record 1 of Set 7 | rocha
# Processing Record 2 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 7 | jeremoabo
# Processing Record 4 of Set 7 | leningradskiy
# Processing Record 5 of Set 7 | koumac
# Processing Record 6 of Set 7 | cururupu
# Processing Record 7 of Set 7 | mount gambier
# Processing Record 8 of Set 7 | sao joao da barra
# Processing Record 9 of Set 7 | luderitz
# Processing Record 10 of Set 7 | san quintin
# Processing Record 11 of Set 7 | neftcala
# Processing Record 12 of Set 7 | havelock
# Processing Record 13 of Set 7 | ponta do sol
# Processing Record 14 of Set 7 | neiafu
# Processing Record 15 of Set 7 | pochutla
# Processing Record 16 of Set 7 | husainabad
# Processing Record 17 of Set 7 | ranong
# Processing Record 18 of Set 7 | caravelas
# Processing Record 19 of Set 7 | san policarpo
# Processing Record 20 of Set 7 | svetlogorsk
# Processing Record 21 of Set 7 | guozhen
# Processing Record 22 of Set 7 | devarkonda
# Processing Record 23 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 7 | jumla
# Processing Record 25 of Set 7 | dobele
# Processing Record 26 of Set 7 | lebu
# Processing Record 27 of Set 7 | vila
# Processing Record 28 of Set 7 | rawson
# Processing Record 29 of Set 7 | warrenton
# Processing Record 30 of Set 7 | baculin
# Processing Record 31 of Set 7 | blackwater
# Processing Record 32 of Set 7 | port hawkesbury
# Processing Record 33 of Set 7 | tautira
# Processing Record 34 of Set 7 | meadow lake
# Processing Record 35 of Set 7 | kroderen
# City not found. Skipping...
# Processing Record 36 of Set 7 | barcs
# Processing Record 37 of Set 7 | hami
# Processing Record 38 of Set 7 | bowen
# Processing Record 39 of Set 7 | struer
# Processing Record 40 of Set 7 | bethel
# Processing Record 41 of Set 7 | krasnogvardeyskiy
# Processing Record 42 of Set 7 | esso
# Processing Record 43 of Set 7 | liverpool
# Processing Record 44 of Set 7 | chokurdakh
# Processing Record 45 of Set 7 | mogadishu
# Processing Record 46 of Set 7 | tual
# Processing Record 47 of Set 7 | asau
# Processing Record 48 of Set 7 | krivosheino
# Processing Record 49 of Set 7 | tucurui
# Processing Record 50 of Set 7 | nishihara
# Processing Record 1 of Set 8 | ciudad bolivar
# Processing Record 2 of Set 8 | hofn
# Processing Record 3 of Set 8 | nador
# Processing Record 4 of Set 8 | las matas de farfan
# Processing Record 5 of Set 8 | taoudenni
# Processing Record 6 of Set 8 | savinka
# Processing Record 7 of Set 8 | khandbari
# Processing Record 8 of Set 8 | kununurra
# Processing Record 9 of Set 8 | panaba
# Processing Record 10 of Set 8 | paris
# Processing Record 11 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 8 | baijiantan
# Processing Record 13 of Set 8 | greenville
# Processing Record 14 of Set 8 | akdepe
# Processing Record 15 of Set 8 | carauari
# Processing Record 16 of Set 8 | omboue
# Processing Record 17 of Set 8 | flinders
# Processing Record 18 of Set 8 | katsuura
# Processing Record 19 of Set 8 | la ronge
# Processing Record 20 of Set 8 | cabedelo
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | snyder
# Processing Record 23 of Set 8 | coquimbo
# Processing Record 24 of Set 8 | mackay
# Processing Record 25 of Set 8 | hasaki
# Processing Record 26 of Set 8 | freeport
# Processing Record 27 of Set 8 | nolinsk
# Processing Record 28 of Set 8 | pemangkat
# Processing Record 29 of Set 8 | sangar
# Processing Record 30 of Set 8 | papar
# Processing Record 31 of Set 8 | newport
# Processing Record 32 of Set 8 | roma
# Processing Record 33 of Set 8 | abu samrah
# Processing Record 34 of Set 8 | berlevag
# Processing Record 35 of Set 8 | mestia
# Processing Record 36 of Set 8 | valea dragului
# Processing Record 37 of Set 8 | gull lake
# Processing Record 38 of Set 8 | kathmandu
# Processing Record 39 of Set 8 | noumea
# Processing Record 40 of Set 8 | lao cai
# Processing Record 41 of Set 8 | ekhabi
# Processing Record 42 of Set 8 | langham
# Processing Record 43 of Set 8 | pokosnoye
# Processing Record 44 of Set 8 | muros
# Processing Record 45 of Set 8 | hvide sande
# Processing Record 46 of Set 8 | zheleznogorsk
# Processing Record 47 of Set 8 | olafsvik
# Processing Record 48 of Set 8 | vite
# Processing Record 49 of Set 8 | bathsheba
# Processing Record 50 of Set 8 | guarulhos
# Processing Record 1 of Set 9 | okhotsk
# Processing Record 2 of Set 9 | bilma
# Processing Record 3 of Set 9 | lasa
# Processing Record 4 of Set 9 | el cristo
# Processing Record 5 of Set 9 | hamilton
# Processing Record 6 of Set 9 | bambanglipuro
# Processing Record 7 of Set 9 | boa vista
# Processing Record 8 of Set 9 | nicoya
# Processing Record 9 of Set 9 | buin
# Processing Record 10 of Set 9 | itaqui
# Processing Record 11 of Set 9 | belfast
# Processing Record 12 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 9 | biak
# Processing Record 14 of Set 9 | arman
# Processing Record 15 of Set 9 | trelew
# Processing Record 16 of Set 9 | mangaratiba
# Processing Record 17 of Set 9 | tsaratanana
# Processing Record 18 of Set 9 | san
# Processing Record 19 of Set 9 | viransehir
# Processing Record 20 of Set 9 | kampene
# Processing Record 21 of Set 9 | norman wells
# Processing Record 22 of Set 9 | aitape
# Processing Record 23 of Set 9 | poum
# Processing Record 24 of Set 9 | port-cartier
# Processing Record 25 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 9 | taltal
# Processing Record 27 of Set 9 | luang prabang
# Processing Record 28 of Set 9 | saskylakh
# Processing Record 29 of Set 9 | manokwari
# Processing Record 30 of Set 9 | dwarka
# Processing Record 31 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 9 | kupang
# Processing Record 33 of Set 9 | cortez
# Processing Record 34 of Set 9 | gravdal
# Processing Record 35 of Set 9 | sao filipe
# Processing Record 36 of Set 9 | finschhafen
# Processing Record 37 of Set 9 | nizhniy baskunchak
# Processing Record 38 of Set 9 | menongue
# Processing Record 39 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 9 | ewa beach
# Processing Record 41 of Set 9 | gayny
# Processing Record 42 of Set 9 | hue
# Processing Record 43 of Set 9 | oistins
# Processing Record 44 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 9 | semirom
# Processing Record 46 of Set 9 | yinchuan
# Processing Record 47 of Set 9 | kandiari
# Processing Record 48 of Set 9 | altoona
# Processing Record 49 of Set 9 | buchanan
# Processing Record 50 of Set 9 | dongkan
# Processing Record 1 of Set 10 | port lincoln
# Processing Record 2 of Set 10 | troitskoye
# Processing Record 3 of Set 10 | ambon
# Processing Record 4 of Set 10 | yishui
# Processing Record 5 of Set 10 | oktyabrskiy
# Processing Record 6 of Set 10 | collie
# Processing Record 7 of Set 10 | jeremie
# Processing Record 8 of Set 10 | muborak
# Processing Record 9 of Set 10 | north platte
# Processing Record 10 of Set 10 | nouadhibou
# Processing Record 11 of Set 10 | ladario
# Processing Record 12 of Set 10 | lata
# Processing Record 13 of Set 10 | ucluelet
# Processing Record 14 of Set 10 | boende
# Processing Record 15 of Set 10 | trabzon
# Processing Record 16 of Set 10 | zharkent
# Processing Record 17 of Set 10 | plettenberg bay
# Processing Record 18 of Set 10 | garowe
# Processing Record 19 of Set 10 | tari
# Processing Record 20 of Set 10 | toamasina
# Processing Record 21 of Set 10 | borazjan
# Processing Record 22 of Set 10 | cockburn town
# Processing Record 23 of Set 10 | ina
# Processing Record 24 of Set 10 | samarai
# Processing Record 25 of Set 10 | pitimbu
# Processing Record 26 of Set 10 | soc trang
# Processing Record 27 of Set 10 | kihei
# Processing Record 28 of Set 10 | isla aguada
# Processing Record 29 of Set 10 | kavaratti
# Processing Record 30 of Set 10 | saint-joseph
# Processing Record 31 of Set 10 | severodvinsk
# Processing Record 32 of Set 10 | aswan
# Processing Record 33 of Set 10 | mayumba
# Processing Record 34 of Set 10 | belyy yar
# Processing Record 35 of Set 10 | marienburg
# Processing Record 36 of Set 10 | kloulklubed
# Processing Record 37 of Set 10 | broken hill
# Processing Record 38 of Set 10 | porto walter
# Processing Record 39 of Set 10 | oksfjord
# Processing Record 40 of Set 10 | erenhot
# Processing Record 41 of Set 10 | dryden
# Processing Record 42 of Set 10 | korem
# Processing Record 43 of Set 10 | isabela
# Processing Record 44 of Set 10 | saint-ambroise
# Processing Record 45 of Set 10 | ankazoabo
# Processing Record 46 of Set 10 | krasnozavodsk
# Processing Record 47 of Set 10 | tiarei
# Processing Record 48 of Set 10 | ribas do rio pardo
# Processing Record 49 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 10 | werda
# Processing Record 1 of Set 11 | udachnyy
# Processing Record 2 of Set 11 | camana
# Processing Record 3 of Set 11 | troitsko-pechorsk
# Processing Record 4 of Set 11 | wanning
# Processing Record 5 of Set 11 | sao joao do paraiso
# Processing Record 6 of Set 11 | atherton
# Processing Record 7 of Set 11 | ewo
# Processing Record 8 of Set 11 | loandjili
# Processing Record 9 of Set 11 | lucea
# Processing Record 10 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 11 | dinard
# Processing Record 12 of Set 11 | viedma
# Processing Record 13 of Set 11 | kruisfontein
# Processing Record 14 of Set 11 | kannangad
# Processing Record 15 of Set 11 | perth
# Processing Record 16 of Set 11 | horta
# Processing Record 17 of Set 11 | aquiraz
# Processing Record 18 of Set 11 | kathu
# Processing Record 19 of Set 11 | nizhniy kuranakh
# Processing Record 20 of Set 11 | elat
# Processing Record 21 of Set 11 | taitung
# Processing Record 22 of Set 11 | cascais
# Processing Record 23 of Set 11 | boa esperanca
# Processing Record 24 of Set 11 | hohhot
# Processing Record 25 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 11 | jardim
# Processing Record 27 of Set 11 | college
# Processing Record 28 of Set 11 | lulea
# Processing Record 29 of Set 11 | calvinia
# Processing Record 30 of Set 11 | araguacu
# Processing Record 31 of Set 11 | raga
# Processing Record 32 of Set 11 | mayo
# Processing Record 33 of Set 11 | safaga
# Processing Record 34 of Set 11 | high level
# Processing Record 35 of Set 11 | naze
# Processing Record 36 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 11 | kamennomostskiy
# Processing Record 38 of Set 11 | namanga
# Processing Record 39 of Set 11 | lalmohan
# Processing Record 40 of Set 11 | nizhniy odes
# Processing Record 41 of Set 11 | san julian
# Processing Record 42 of Set 11 | kodinsk
# Processing Record 43 of Set 11 | elko
# Processing Record 44 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 11 | challapata
# Processing Record 46 of Set 11 | uruzgan
# Processing Record 47 of Set 11 | bluefield
# Processing Record 48 of Set 11 | coruripe
# Processing Record 49 of Set 11 | paita
# Processing Record 50 of Set 11 | banjar
# Processing Record 1 of Set 12 | anchorage
# Processing Record 2 of Set 12 | saint-philippe
# Processing Record 3 of Set 12 | preobrazheniye
# Processing Record 4 of Set 12 | ponta delgada
# Processing Record 5 of Set 12 | kavieng
# Processing Record 6 of Set 12 | quatre cocos
# Processing Record 7 of Set 12 | hirara
# Processing Record 8 of Set 12 | north bend
# Processing Record 9 of Set 12 | kearney
# Processing Record 10 of Set 12 | jacksonville
# Processing Record 11 of Set 12 | khasan
# Processing Record 12 of Set 12 | ambalavao
# Processing Record 13 of Set 12 | pahrump
# Processing Record 14 of Set 12 | roswell
# Processing Record 15 of Set 12 | kysyl-syr
# Processing Record 16 of Set 12 | jinchang
# Processing Record 17 of Set 12 | ballina
# Processing Record 18 of Set 12 | tevaitoa
# Processing Record 19 of Set 12 | gillette
# Processing Record 20 of Set 12 | altamira
# Processing Record 21 of Set 12 | dudinka
# Processing Record 22 of Set 12 | la palma
# Processing Record 23 of Set 12 | sibolga
# Processing Record 24 of Set 12 | berezovyy
# Processing Record 25 of Set 12 | lorengau
# Processing Record 26 of Set 12 | padang
# Processing Record 27 of Set 12 | necochea
# Processing Record 28 of Set 12 | tahe
# Processing Record 29 of Set 12 | maceio
# Processing Record 30 of Set 12 | pringsewu
# Processing Record 31 of Set 12 | neuquen
# Processing Record 32 of Set 12 | santa cruz
# Processing Record 33 of Set 12 | anito
# Processing Record 34 of Set 12 | yar-sale
# Processing Record 35 of Set 12 | augusto correa
# Processing Record 36 of Set 12 | boo
# Processing Record 37 of Set 12 | baruun-urt
# Processing Record 38 of Set 12 | boueni
# Processing Record 39 of Set 12 | carmen
# Processing Record 40 of Set 12 | wajir
# Processing Record 41 of Set 12 | bam
# Processing Record 42 of Set 12 | troy
# Processing Record 43 of Set 12 | egvekinot
# Processing Record 44 of Set 12 | ribeira brava
# Processing Record 45 of Set 12 | griffith
# Processing Record 46 of Set 12 | oranjestad
# Processing Record 47 of Set 12 | riverton
# Processing Record 48 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 12 | vytegra
# Processing Record 50 of Set 12 | sabha
# Processing Record 1 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 2 of Set 13 | toppenish
# Processing Record 3 of Set 13 | sita buzaului
# Processing Record 4 of Set 13 | gazanjyk
# Processing Record 5 of Set 13 | tura
# Processing Record 6 of Set 13 | almora
# Processing Record 7 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 13 | ixtapa
# Processing Record 9 of Set 13 | ejea de los caballeros
# Processing Record 10 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 13 | mbanza-ngungu
# Processing Record 12 of Set 13 | mayor pablo lagerenza
# Processing Record 13 of Set 13 | beidao
# Processing Record 14 of Set 13 | rudbar
# Processing Record 15 of Set 13 | bandarbeyla
# Processing Record 16 of Set 13 | nioro
# Processing Record 17 of Set 13 | komsomolskiy
# Processing Record 18 of Set 13 | homer
# Processing Record 19 of Set 13 | biltine
# Processing Record 20 of Set 13 | denham springs
# Processing Record 21 of Set 13 | gbarnga
# Processing Record 22 of Set 13 | usoke
# Processing Record 23 of Set 13 | vastervik
# City not found. Skipping...
# Processing Record 24 of Set 13 | port-gentil
# Processing Record 25 of Set 13 | bac lieu
# Processing Record 26 of Set 13 | pontianak
# Processing Record 27 of Set 13 | auxerre
# Processing Record 28 of Set 13 | lashio
# Processing Record 29 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 13 | kabo
# Processing Record 31 of Set 13 | vao
# Processing Record 32 of Set 13 | toma
# Processing Record 33 of Set 13 | rubiataba
# Processing Record 34 of Set 13 | madimba
# Processing Record 35 of Set 13 | chaman
# Processing Record 36 of Set 13 | sucua
# Processing Record 37 of Set 13 | ukiah
# Processing Record 38 of Set 13 | aberdeen
# Processing Record 39 of Set 13 | koubia
# Processing Record 40 of Set 13 | pelym
# Processing Record 41 of Set 13 | pisco
# Processing Record 42 of Set 13 | hegang
# Processing Record 43 of Set 13 | boyolangu
# Processing Record 44 of Set 13 | kwekwe
# Processing Record 45 of Set 13 | bor
# Processing Record 46 of Set 13 | eureka
# Processing Record 47 of Set 13 | guymon
# Processing Record 48 of Set 13 | leopold
# Processing Record 49 of Set 13 | excelsior springs
# Processing Record 50 of Set 13 | auki
# Processing Record 1 of Set 14 | devils lake
# Processing Record 2 of Set 14 | sinnar
# Processing Record 3 of Set 14 | isla mujeres
# Processing Record 4 of Set 14 | nyurba
# Processing Record 5 of Set 14 | ouadda
# Processing Record 6 of Set 14 | tateyama
# Processing Record 7 of Set 14 | raudeberg
# Processing Record 8 of Set 14 | los andes
# Processing Record 9 of Set 14 | parral
# Processing Record 10 of Set 14 | honiara
# Processing Record 11 of Set 14 | mubi
# Processing Record 12 of Set 14 | ayamonte
# Processing Record 13 of Set 14 | kilindoni
# Processing Record 14 of Set 14 | borger
# Processing Record 15 of Set 14 | upington
# Processing Record 16 of Set 14 | karratha
# Processing Record 17 of Set 14 | shitanjing
# Processing Record 18 of Set 14 | athens
# Processing Record 19 of Set 14 | gloversville
# Processing Record 20 of Set 14 | dawei
# Processing Record 21 of Set 14 | matagami
# Processing Record 22 of Set 14 | ulaangom
# Processing Record 23 of Set 14 | antofagasta
# Processing Record 24 of Set 14 | fairbanks
# Processing Record 25 of Set 14 | hondo
# Processing Record 26 of Set 14 | puerto madryn
# Processing Record 27 of Set 14 | sakakah
# Processing Record 28 of Set 14 | kayes
# Processing Record 29 of Set 14 | dundalk
# Processing Record 30 of Set 14 | marzuq
# Processing Record 31 of Set 14 | petrolia
# Processing Record 32 of Set 14 | todos santos
# Processing Record 33 of Set 14 | usinsk
# Processing Record 34 of Set 14 | solnechnyy
# Processing Record 35 of Set 14 | bartica
# Processing Record 36 of Set 14 | tutoia
# Processing Record 37 of Set 14 | tanete
# Processing Record 38 of Set 14 | tessalit
# Processing Record 39 of Set 14 | niquero
# Processing Record 40 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 41 of Set 14 | jiwani
# Processing Record 42 of Set 14 | rengo
# Processing Record 43 of Set 14 | afsin
# Processing Record 44 of Set 14 | yanam
# Processing Record 45 of Set 14 | airai
# Processing Record 46 of Set 14 | zhigansk
# Processing Record 47 of Set 14 | xiongyue
# Processing Record 48 of Set 14 | ndjole
# Processing Record 49 of Set 14 | rastu
# Processing Record 50 of Set 14 | dali
# Processing Record 1 of Set 15 | bud
# Processing Record 2 of Set 15 | guerrero negro
# Processing Record 3 of Set 15 | bakaly
# Processing Record 4 of Set 15 | ashland
# Processing Record 5 of Set 15 | bairiki
# Processing Record 6 of Set 15 | klooga
# Processing Record 7 of Set 15 | kouango
# Processing Record 8 of Set 15 | macusani
# Processing Record 9 of Set 15 | comodoro rivadavia
# Processing Record 10 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 11 of Set 15 | bagdarin
# Processing Record 12 of Set 15 | saint-augustin
# Processing Record 13 of Set 15 | lahaina
# Processing Record 14 of Set 15 | tchaourou
# Processing Record 15 of Set 15 | acapulco
# Processing Record 16 of Set 15 | cayenne
# Processing Record 17 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 15 | skjervoy
# Processing Record 19 of Set 15 | back mountain
# Processing Record 20 of Set 15 | sakaiminato
# Processing Record 21 of Set 15 | maragogi
# Processing Record 22 of Set 15 | sept-iles
# Processing Record 23 of Set 15 | axim
# Processing Record 24 of Set 15 | mananjary
# Processing Record 25 of Set 15 | taunggyi
# Processing Record 26 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 15 | dodoma
# Processing Record 28 of Set 15 | numaligarh
# Processing Record 29 of Set 15 | kolochava
# Processing Record 30 of Set 15 | xinpu
# Processing Record 31 of Set 15 | sosva
# Processing Record 32 of Set 15 | rosario
# Processing Record 33 of Set 15 | general roca
# Processing Record 34 of Set 15 | phrae
# Processing Record 35 of Set 15 | vryburg
# Processing Record 36 of Set 15 | mumford
# Processing Record 37 of Set 15 | vanimo
# Processing Record 38 of Set 15 | namibe
# Processing Record 39 of Set 15 | pangody
# Processing Record 40 of Set 15 | half moon bay
# Processing Record 41 of Set 15 | wageningen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 687

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df.drop("Date", axis=1)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaanaaq  77.4840  -69.3632     -3.06        61           0
# 1     Ulladulla -35.3500  150.4667     64.29        84           5
# 2        Castro -24.7911  -50.0119     60.12        93         100
# 3  Saint-Pierre -21.3393   55.4781     73.08        64          40
# 4   Tuktoyaktuk  69.4541 -133.0374     24.80        93         100
# 5    Bredasdorp -34.5322   20.0403     63.55        96          73
# 6      Cidreira -30.1811  -50.2056     66.87        87         100
# 7       Aksarka  66.5606   67.7975      4.10        95          73
# 8          Nuuk  64.1835  -51.7216     23.61        63          75
# 9         Alofi -19.0595 -169.9187     80.49        74          75
#
#    Wind Speed Country       Description
# 0        7.25      GL         clear sky
# 1        5.19      AU         clear sky
# 2        3.87      BR   overcast clouds
# 3        5.75      RE  scattered clouds
# 4       11.50      CA        light snow
# 5        3.27      ZA     broken clouds
# 6       11.05      BR   overcast clouds
# 7       13.58      RU     broken clouds
# 8       10.36      GL     broken clouds
# 9       11.50      NU     broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]


# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Qaanaaq      GL  77.4840  -69.3632     -3.06        61           0
# 1     Ulladulla      AU -35.3500  150.4667     64.29        84           5
# 2        Castro      BR -24.7911  -50.0119     60.12        93         100
# 3  Saint-Pierre      RE -21.3393   55.4781     73.08        64          40
# 4   Tuktoyaktuk      CA  69.4541 -133.0374     24.80        93         100
# 5    Bredasdorp      ZA -34.5322   20.0403     63.55        96          73
# 6      Cidreira      BR -30.1811  -50.2056     66.87        87         100
# 7       Aksarka      RU  66.5606   67.7975      4.10        95          73
# 8          Nuuk      GL  64.1835  -51.7216     23.61        63          75
# 9         Alofi      NU -19.0595 -169.9187     80.49        74          75
#
#    Wind Speed       Description
# 0        7.25         clear sky
# 1        5.19         clear sky
# 2        3.87   overcast clouds
# 3        5.75  scattered clouds
# 4       11.50        light snow
# 5        3.27     broken clouds
# 6       11.05   overcast clouds
# 7       13.58     broken clouds
# 8       10.36     broken clouds
# 9       11.50     broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
